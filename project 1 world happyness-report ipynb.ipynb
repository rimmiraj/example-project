# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('C:\\Users\pc\\Desktop\\.ipynb_checkpoints\\world happyness-report.csv')

# %%
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
df.shape
# Out:
# (158, 12)

# %%
df['Region'].unique()
# Out:
# array(['Western Europe', 'North America', 'Australia and New Zealand',
#        'Middle East and Northern Africa', 'Latin America and Caribbean',
#        'Southeastern Asia', 'Central and Eastern Europe', 'Eastern Asia',
#        'Sub-Saharan Africa', 'Southern Asia'], dtype=object)

# %%
pd.DataFrame(dict(df['Region'].value_counts()).items(), columns = ['Region','Numbers'])
# Out:
#                             Region  Numbers
# 0               Sub-Saharan Africa       40
# 1       Central and Eastern Europe       29
# 2      Latin America and Caribbean       22
# 3                   Western Europe       21
# 4  Middle East and Northern Africa       20
# 5                Southeastern Asia        9
# 6                    Southern Asia        7
# 7                     Eastern Asia        6
# 8                    North America        2
# 9        Australia and New Zealand        2

# %%
corr= df.corr()

# %%
corr
# Out:
#                                Happiness Rank  Happiness Score  \
# Happiness Rank                       1.000000        -0.992105
# Happiness Score                     -0.992105         1.000000
# Standard Error                       0.158516        -0.177254
# Economy (GDP per Capita)            -0.785267         0.780966
# Family                              -0.733644         0.740605
# Health (Life Expectancy)            -0.735613         0.724200
# Freedom                             -0.556886         0.568211
# Trust (Government Corruption)       -0.372315         0.395199
# Generosity                          -0.160142         0.180319
# Dystopia Residual                   -0.521999         0.530474
#
#                                Standard Error  Economy (GDP per Capita)  \
# Happiness Rank                       0.158516                 -0.785267
# Happiness Score                     -0.177254                  0.780966
# ...

# %%
sns.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %%
df_new = df.drop(['Happiness Rank'],axis=1)

# %%
corrmat = df_new.corr()

# %%
f, ax = plt.subplots(figsize=(10,10))
sns.heatmap(corrmat,annot=True,square=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # basic visulazation

# %% [markdown]
# # Happiness Score by Region

# %%
plt.figure(figsize=(15,10))
sns.barplot(x='Happiness Rank',y='Region',data = df, palette = 'viridis')
plt.xlabel('country name')
plt.ylabel('rank according country')
plt.title('Happiness Score by Region', fontsize = '20')
plt.xticks(rotation = 90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Happiness Score of top 25 Countries

# %%
plt.figure(figsize = (15,6))
sns.barplot(x ='Happiness Score',y= 'Country',data = df.nlargest(20,'Happiness Score'), palette = 'viridis')
plt.title('Happiness Score of top 25 Countries', fontsize = 20)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # switzerland on of the most happyist score

# %% [markdown]
# # analyze Economy (GDP per Capita)

# %%
import seaborn as sns
plt.figure(figsize = (15,6))
sns.barplot(x ='Economy (GDP per Capita)',y= 'Region',data = df, palette = 'Spectral')
plt.title('GDP Per Capita by Region', fontsize = '20')
plt.xticks(rotation = 90)
plt.show()

# %%
import seaborn as sns
plt.figure(figsize = (15,10))
sns.barplot(x ='Economy (GDP per Capita)',y= 'Country',data = df.nlargest(25,'Economy (GDP per Capita)'), palette = 'Spectral')
plt.title('GDP Per Capita of top 25 Countries', fontsize = '20')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # Freedom by region

# %%
import seaborn as sns
plt.figure(figsize = (15,6))
sns.barplot(x ='Freedom',y= 'Region',data = df, palette = 'cubehelix')
plt.title('Freedom by Region', fontsize = 20)
plt.xticks(rotation = 90)
plt.show()

# %%
import seaborn as sns
plt.figure(figsize = (15,10))
sns.barplot(x ='Freedom',y= 'Country',data = df.nlargest(25,'Freedom'), palette = 'cubehelix')
plt.title('Freedom of top 25 Countries', fontsize = 20)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # Trust (Government Corruption) BY REGION

# %%
import seaborn as sns
plt.figure(figsize = (15,6))
sns.barplot(x ='Trust (Government Corruption)',y= 'Region',data = df, palette = 'vlag')
plt.title('Trust (Government Corruption) by Region', fontsize = 20)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # trust (Government Corruption) by country

# %%
import seaborn as sns
plt.figure(figsize = (15,10))
sns.barplot(x ='Trust (Government Corruption)',y= 'Country',data = df.nlargest(25,'Trust (Government Corruption)'), palette = 'vlag')
plt.title('Trust (Government Corruption) of  Countries', fontsize = 20)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# # Prediction Models

# %%
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %% [markdown]
# # country or region are not important features

# %%
df = df.drop(['Country','Region'],axis=1)

# %%
df.head()
# Out:
#    Happiness Rank  Happiness Score  Standard Error  Economy (GDP per Capita)  \
# 0               1            7.587         0.03411                   1.39651
# 1               2            7.561         0.04884                   1.30232
# 2               3            7.527         0.03328                   1.32548
# 3               4            7.522         0.03880                   1.45900
# 4               5            7.427         0.03553                   1.32629
#
#     Family  Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0  1.34951                   0.94143  0.66557                        0.41978
# 1  1.40223                   0.94784  0.62877                        0.14145
# 2  1.36058                   0.87464  0.64938                        0.48357
# 3  1.33095                   0.88521  0.66973                        0.36503
# 4  1.32261                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# ...

# %%
df.columns
# Out:
# Index(['Happiness Rank', 'Happiness Score', 'Standard Error',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual'],
#       dtype='object')

# %%
x = ['Happiness Rank','Standard Error',
       'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
       'Freedom', 'Trust (Government Corruption)', 'Generosity',
       'Dystopia Residual']

# %%
y = ['Happiness Score']

# %%
x = df.drop(['Happiness Score'],axis=1)
y = df['Happiness Score']

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix,classification_report

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.20,random_state=41)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train, y_train)
regressor.score(x_test, y_test)
# Out:
# 0.9999999435840006

# %%
from sklearn.ensemble import RandomForestRegressor
regressor_forest = RandomForestRegressor(n_estimators = 10, random_state = 41)
regressor_forest.fit(x_train, y_train)
regressor_forest.score(x_test,y_test)
# Out:
# 0.9947447294311053

# %%
from sklearn.tree import DecisionTreeRegressor

regressor = DecisionTreeRegressor(random_state = 42)
regressor.fit(x_train, y_train)
regressor.score(x_test,y_test)
# Out:
# 0.9869800461092811

# %%
from sklearn.linear_model import Ridge
rid = Ridge(alpha=1)
rid.fit(x_train,y_train)
rid.score(x_test,y_test)
# Out:
# 0.9925872470003763

# %%
from sklearn.ensemble import GradientBoostingRegressor
boost = GradientBoostingRegressor()
boost.fit(x_train,y_train)
boost.score(x_test,y_test)
# Out:
# 0.9956715574069714

# %%
from sklearn.ensemble import AdaBoostRegressor

ada = AdaBoostRegressor()
ada.fit(x_train,y_train)
ada.score(x_test,y_test)
# Out:
# 0.9916056113350284

# %% [markdown]
# best accuracy randomforest
