# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame({'name':['arun','ankit',np.nan,'pankaj','ramesh','kajal'],
'roll_no':[1,np.nan,np.nan,2,2,3],
'gali_no':[11,12,13,np.nan,14,15]})

# %%
df
# Out:
#      name  roll_no  gali_no
# 0    arun      1.0     11.0
# 1   ankit      NaN     12.0
# 2     NaN      NaN     13.0
# 3  pankaj      2.0      NaN
# 4  ramesh      2.0     14.0
# 5   kajal      3.0     15.0

# %% [markdown]
# missing value

# %%
df.isna().sum()
# Out:
# name       1
# roll_no    2
# gali_no    1
# dtype: int64

# %%
#dropna function to use all null value remove

# %%
df.dropna()
# Out:
#      name  roll_no  gali_no
# 0    arun      1.0     11.0
# 4  ramesh      2.0     14.0
# 5   kajal      3.0     15.0

# %%
df
# Out:
#      name  roll_no  gali_no
# 0    arun      1.0     11.0
# 1   ankit      NaN     12.0
# 2     NaN      NaN     13.0
# 3  pankaj      2.0      NaN
# 4  ramesh      2.0     14.0
# 5   kajal      3.0     15.0

# %%
df.fillna(0)
# Out:
#      name  roll_no  gali_no
# 0    arun      1.0     11.0
# 1   ankit      0.0     12.0
# 2       0      0.0     13.0
# 3  pankaj      2.0      0.0
# 4  ramesh      2.0     14.0
# 5   kajal      3.0     15.0

# %% [markdown]
# # handling this type null value

# %%
#missing_value = ['na','n/a',np.nan]
#df2 = pd.read_csv('data.csv',na_values=missing_values)

# %%
df
# Out:
#      name  roll_no  gali_no
# 0    arun      1.0     11.0
# 1   ankit      NaN     12.0
# 2     NaN      NaN     13.0
# 3  pankaj      2.0      NaN
# 4  ramesh      2.0     14.0
# 5   kajal      3.0     15.0

# %%
df.fillna(method='ffill')
# Out:
#      name  roll_no  gali_no
# 0    arun      1.0     11.0
# 1   ankit      1.0     12.0
# 2   ankit      1.0     13.0
# 3  pankaj      2.0     13.0
# 4  ramesh      2.0     14.0
# 5   kajal      3.0     15.0

# %%
df
# Out:
#      name  roll_no  gali_no
# 0    arun      1.0     11.0
# 1   ankit      NaN     12.0
# 2     NaN      NaN     13.0
# 3  pankaj      2.0      NaN
# 4  ramesh      2.0     14.0
# 5   kajal      3.0     15.0

# %%
df.fillna(method='bfill')
# Out:
#      name  roll_no  gali_no
# 0    arun      1.0     11.0
# 1   ankit      2.0     12.0
# 2  pankaj      2.0     13.0
# 3  pankaj      2.0     14.0
# 4  ramesh      2.0     14.0
# 5   kajal      3.0     15.0

# %%
df
# Out:
#      name  roll_no  gali_no
# 0    arun      1.0     11.0
# 1   ankit      NaN     12.0
# 2     NaN      NaN     13.0
# 3  pankaj      2.0      NaN
# 4  ramesh      2.0     14.0
# 5   kajal      3.0     15.0

# %%
df.interpolate()
# Out:
#      name   roll_no  gali_no
# 0    arun  1.000000     11.0
# 1   ankit  1.333333     12.0
# 2     NaN  1.666667     13.0
# 3  pankaj  2.000000     13.5
# 4  ramesh  2.000000     14.0
# 5   kajal  3.000000     15.0

# %%
df['name']= df['name'].fillna(method='bfill')

# %%
df
# Out:
#      name  roll_no  gali_no
# 0    arun      1.0     11.0
# 1   ankit      NaN     12.0
# 2  pankaj      NaN     13.0
# 3  pankaj      2.0      NaN
# 4  ramesh      2.0     14.0
# 5   kajal      3.0     15.0

# %%
df['roll_no'] = df['roll_no'].fillna(0)

# %%
df
# Out:
#      name  roll_no  gali_no
# 0    arun      1.0     11.0
# 1   ankit      0.0     12.0
# 2  pankaj      0.0     13.0
# 3  pankaj      2.0      NaN
# 4  ramesh      2.0     14.0
# 5   kajal      3.0     15.0

# %%
df
# Out:
#      name  roll_no  gali_no
# 0    arun      1.0     11.0
# 1   ankit      0.0     12.0
# 2  pankaj      0.0     13.0
# 3  pankaj      2.0      NaN
# 4  ramesh      2.0     14.0
# 5   kajal      3.0     15.0

# %%
df.gali_no.mean()
# Out:
# 13.0

# %%
df.fillna(13)
# Out:
#      name  roll_no  gali_no
# 0    arun      1.0     11.0
# 1   ankit      0.0     12.0
# 2  pankaj      0.0     13.0
# 3  pankaj      2.0     13.0
# 4  ramesh      2.0     14.0
# 5   kajal      3.0     15.0
